# %% [markdown]
# # Assignment Part 2: Segmentation of Human Blood Cells using Convolutional Neural Networks
# _By David Holmberg (2023)_
#
# Welcome to Task 3! In this assignment you will segment Leukocytes using both scratch-built models and  pre-defined downloaded models.
#
# Hand-in: Quiz on Studium.
#
# For this lab, we use the [Human White Blood Cell images](https://github.com/zxaoyou/segmentation_WBC) from [Jiangxi Tecom Science Corporation, China](http://en.tecom-cn.com/).
#
# The dataset contains three hundred 120x120 RGB images with one blood cell per image, and corresponding segmentation masks. The segmentation mask was manually sketched by domain experts, with the background, cytoplasms and nuclei pixels labelled as 0, 1 and 2 respectively.
#
# <img src="Illustrations/Dataset_1.png" title="Blood cells dataset" align="left"/>

# %% [markdown]
# These images and masks are in the **LabData/bloodcells_seg/** folder:
# ```
# └── LabData
#     └── bloodcells_seg
#         ├── masks
#         │   ├── all
#         └── images
#             ├── all
# ```
#
# We want to use convolutional neural networks to do pixel-wise classification of these blood cells images into background / cytoplasm / nuclei.
#
# This assignment is based on and borrows *heavily* from a lab written by Christophe Avenel at NBIS, and his code is available here: https://github.com/NBISweden/workshop-neural-nets-and-deep-learning/tree/master/session_convolutionalNeuralNetworks/Labs
#
# So please remember that he is the original author of this assignment.

# %%
# First we import useful modules like numpy and Keras layers

import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
# cnn_helper contains some useful functions for this lab
import cnn_helper
from IPython.display import IFrame
import tensorflow as tf
from tensorflow import keras
from keras import layers
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import os
os.environ["SM_FRAMEWORK"]="tf.keras"
import segmentation_models as sm

# %% [markdown]
# We will load both the images and the masks as generators, and combine both generators into a zip of generators.

# %%
IMG_SIZE = 128
NUM_CLASSES = 3 # Background, cytoplasm, nuclei
N_CHANNELS = 3  # R,G,B
BATCH_SIZE = 8  # You can tune this and see which batch size runs faster / gives the best accuracy.


train_steps = 240/BATCH_SIZE
val_steps = 64/BATCH_SIZE


seed = 909 # (IMPORTANT) to transform image and corresponding mask with same augmentation parameter.
image_datagen = ImageDataGenerator(
    validation_split=0.2,
    rescale=1./255 #We need to rescale png images from 0-255 integers to 0.0-1.0 floats.
)
mask_datagen = ImageDataGenerator(
    validation_split=0.2
)

# Load image and mask generators for training:
train_image_generator = image_datagen.flow_from_directory(
    directory='/scratch-shared/students/DeepLearning/LabData/bloodcells_seg/images/',
    batch_size=BATCH_SIZE,
    target_size=(IMG_SIZE,IMG_SIZE),
    class_mode=None, 
    seed=seed,
    subset='training',
    color_mode='rgb',
    shuffle=False)
# Note: the class_mode is used when the class is extracted from the directory
# structure. Here the class will be defined by the mask from the generator below, 
# so we add class_mode: None

train_mask_generator = mask_datagen.flow_from_directory(
    directory='/scratch-shared/students/DeepLearning/LabData/bloodcells_seg/masks/',
    batch_size=BATCH_SIZE,
    target_size=(IMG_SIZE,IMG_SIZE),
    class_mode=None,
    seed=seed,
    subset='training',
    color_mode='grayscale',
    shuffle=False)

train_generator = zip(train_image_generator, train_mask_generator)

# Load image and mask  generators for validation:
val_image_generator = image_datagen.flow_from_directory(
    directory='/scratch-shared/students/DeepLearning/LabData/bloodcells_seg/images/',
    batch_size=BATCH_SIZE,
    target_size=(IMG_SIZE,IMG_SIZE),
    class_mode=None,
    seed=seed,
    subset='validation',
    color_mode='rgb',
    shuffle=False)

val_mask_generator = mask_datagen.flow_from_directory(
    directory='/scratch-shared/students/DeepLearning/LabData/bloodcells_seg/masks/',
    batch_size=BATCH_SIZE,
    target_size=(IMG_SIZE,IMG_SIZE),
    class_mode=None,
    seed=seed,
    subset='validation',
    color_mode='grayscale',
    shuffle=False)

val_generator = zip(val_image_generator, val_mask_generator)
# Out:
# Found 240 images belonging to 1 classes.
# Found 240 images belonging to 1 classes.
# Found 60 images belonging to 1 classes.
# Found 60 images belonging to 1 classes.

# %% [markdown]
# We can now check that the generators deliver our data:

# %%
cMap = ListedColormap(['red', 'lime', 'blue'])

images,masks = next(train_generator)
for i in range(0,2):
    plt.figure()
    plt.imshow(images[i], cmap=cMap)
    plt.figure()
    plt.imshow(masks[i,:,:,0], cmap=cMap)

# %% [markdown]
# For this assignment you will build a UNET model. You can see an illustration of the model below, and we have provided a base model for you to tweak, as it must still comply with the data we have provided.
#
# <img src="Illustrations/unet.png" title="Unet model"/>

# %%
def conv_block(x, filters, kernel_size=3, activation='relu', padding='same', dropout_rate=0.1, include_pool=True):
    c = layers.Conv2D(filters, (kernel_size, kernel_size), activation=activation, kernel_initializer='he_normal', padding=padding)(x)
    c = layers.Dropout(dropout_rate)(c)
    c = layers.Conv2D(filters, (kernel_size, kernel_size), activation=activation, kernel_initializer='he_normal', padding=padding)(c)
    if include_pool:
        p = layers.MaxPooling2D((2, 2))(c)
        return c, p
    else:
        return c
    
def upconv_block(x, skip, filters, kernel_size=3, activation='relu', padding='same', dropout_rate=0.1):
    u = layers.Conv2DTranspose(filters, (2, 2), strides=(2, 2), padding='same')(x)
    u = layers.concatenate([u, skip])
    c = layers.Conv2D(filters, (kernel_size, kernel_size), activation=activation, kernel_initializer='he_normal', padding=padding)(u)
    c = layers.Dropout(dropout_rate)(c)
    c = layers.Conv2D(filters, (kernel_size, kernel_size), activation=activation, kernel_initializer='he_normal', padding=padding)(c)
    return c



inputs = layers.Input((IMG_SIZE, IMG_SIZE, N_CHANNELS))
x = inputs

# Encoder (Contracting Path)
skip_connections = []
for filters in [16, 32, 64, 128]:
    x, p = conv_block(x, filters)
    skip_connections.append(x)
    x = p

# Bottleneck
x = conv_block(x, 256, dropout_rate=0.3, include_pool=False)

# Decoder (Expansive Path)
for i, filters in enumerate([128, 64, 32, 16]):
    x = upconv_block(x, skip_connections[-(i + 1)], filters)

# Output
outputs = layers.Conv2D(NUM_CLASSES, (1, 1), activation='softmax')(x)

# %% [markdown]
# We will use the Keras SparseCategoricalCrossentropy loss function (see https://www.tensorflow.org/api_docs/python/tf/keras/losses/SparseCategoricalCrossentropy).
#
# because our ground truth is represented by integers on a mask (0 for background, 1 for cytoplasm, 2 for nuclei pixels) this becomes a good choice.
#
# Please define, summarize, and compile it in the following three cells:
#
# **tip:** you'll want to define the loss specifically, i.e use tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False) and not 'SparseCategoricalCrossentropy' as before.
#
# **tip:** you can define the learning rate specifically in Adam() inside the parenthesis. I suggest you start with 0.0001.

# %%
model = keras.Model(inputs=[inputs], outputs=[outputs])

model.compile(optimizer=Adam(
    learning_rate=0.0001), loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
    )

# %% [markdown]
# ### NOTE
#
# While Relu is considered fairly standard to use, you can try replacing it with selu, gelu, elu, relu6, LeakyRelu. WIth most of these, it is enough to just replace 'relu'. However, LeakyRelu requires a bit of extra code. Search for it if you want to try it!

# %% [markdown]
# ## train
# Now you will train the network.
#
# Look back at how you trained your model in the previous Assignment.
#
# You can track the progress of your training using the callback function we've defined for you in the cell below. you can do this by adding ```callbacks=[plot_callback]``` at the end of your model.fit_generator function.

# %%
#train the network:
epochs = 50

plot_callback = cnn_helper.PlottingKerasCallback(
    test_batch=next(val_generator),
    num_plot=3 # how many validation examples to plot at each epoch (maximum = BATCH_SIZE)
)

model.fit_generator(
    generator=train_generator,
    steps_per_epoch= train_steps,
    validation_data= val_generator,
    validation_steps= val_steps,
    epochs= epochs,
    #callbacks=[plot_callback]
)
# Out:
# Epoch 1/50
# /tmp/ipykernel_80959/2307443767.py:9: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(
# 2024-01-28 20:04:43.361920: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2024-01-28 20:04:45.336900: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_1/dropout_9/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 29/30 [============================>.] - ETA: 0s - loss: 1.2081 - accuracy: 0.4725
# 2024-01-28 20:04:50.325769: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 30/30 [==============================] - 7s 31ms/step - loss: 1.1918 - accuracy: 0.4870 - val_loss: 0.7076 - val_accuracy: 0.9463
# Epoch 2/50
# 30/30 [==============================] - 1s 21ms/step - loss: 0.5442 - accuracy: 0.9031 - val_loss: 0.4192 - val_accuracy: 0.8060
# Epoch 3/50
# 30/30 [==============================] - 1s 20ms/step - loss: 0.3942 - accuracy: 0.7850 - val_loss: 0.3630 - val_accuracy: 0.7737
# Epoch 4/50
# 30/30 [==============================] - 1s 20ms/step - loss: 0.3415 - accuracy: 0.7642 - val_loss: 0.3148 - val_accuracy: 0.7827
# Epoch 5/50
# 30/30 [==============================] - 1s 19ms/step - loss: 0.2973 - accuracy: 0.7549 - val_loss: 0.2748 - val_accuracy: 0.7797
# Epoch 6/50
# 30/30 [==============================] - 1s 21ms/step - loss: 0.2417 - accuracy: 0.7426 - val_loss: 0.2266 - val_accuracy: 0.7736
# Epoch 7/50
# 30/30 [==============================] - 1s 21ms/step - loss: 0.1995 - accuracy: 0.7313 - val_loss: 0.2059 - val_accuracy: 0.7647
# Epoch 8/50
# 30/30 [==============================] - 1s 21ms/step - loss: 0.1809 - accuracy: 0.7284 - val_loss: 0.2051 - val_accuracy: 0.7682
# Epoch 9/50
# 30/30 [==============================] - 1s 21ms/step - loss: 0.1679 - accuracy: 0.7268 - val_loss: 0.1995 - val_accuracy: 0.7655
# Epoch 10/50
# 30/30 [==============================] - 1s 20ms/step - loss: 0.1624 - accuracy: 0.7279 - val_loss: 0.1677 - val_accuracy: 0.7443
# Epoch 11/50
# 30/30 [==============================] - 1s 22ms/step - loss: 0.1522 - accuracy: 0.7280 - val_loss: 0.1610 - val_accuracy: 0.7455
# Epoch 12/50
# 30/30 [==============================] - 1s 22ms/step - loss: 0.1407 - accuracy: 0.7262 - val_loss: 0.1529 - val_accuracy: 0.7462
# Epoch 13/50
# 30/30 [==============================] - 1s 22ms/step - loss: 0.1393 - accuracy: 0.7273 - val_loss: 0.1473 - val_accuracy: 0.7446
# Epoch 14/50
# 30/30 [==============================] - 1s 21ms/step - loss: 0.1296 - accuracy: 0.7266 - val_loss: 0.1410 - val_accuracy: 0.7453
# Epoch 15/50
# 30/30 [==============================] - 1s 20ms/step - loss: 0.1268 - accuracy: 0.7266 - val_loss: 0.1292 - val_accuracy: 0.7429
# Epoch 16/50
# 30/30 [==============================] - 1s 21ms/step - loss: 0.1221 - accuracy: 0.7268 - val_loss: 0.1291 - val_accuracy: 0.7415
# Epoch 17/50
# 30/30 [==============================] - 1s 19ms/step - loss: 0.1161 - accuracy: 0.7265 - val_loss: 0.1354 - val_accuracy: 0.7463
# Epoch 18/50
# 30/30 [==============================] - 1s 20ms/step - loss: 0.1146 - accuracy: 0.7271 - val_loss: 0.1159 - val_accuracy: 0.7408
# Epoch 19/50
# 30/30 [==============================] - 1s 21ms/step - loss: 0.1075 - accuracy: 0.7267 - val_loss: 0.1166 - val_accuracy: 0.7447
# Epoch 20/50
# 30/30 [==============================] - 1s 21ms/step - loss: 0.1052 - accuracy: 0.7265 - val_loss: 0.1113 - val_accuracy: 0.7444
# Epoch 21/50
# 30/30 [==============================] - 1s 21ms/step - loss: 0.1036 - accuracy: 0.7272 - val_loss: 0.1076 - val_accuracy: 0.7416
# Epoch 22/50
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0984 - accuracy: 0.7268 - val_loss: 0.1088 - val_accuracy: 0.7424
# Epoch 23/50
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0944 - accuracy: 0.7266 - val_loss: 0.1066 - val_accuracy: 0.7458
# Epoch 24/50
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0938 - accuracy: 0.7271 - val_loss: 0.1051 - val_accuracy: 0.7455
# Epoch 25/50
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0895 - accuracy: 0.7267 - val_loss: 0.1016 - val_accuracy: 0.7467
# Epoch 26/50
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0896 - accuracy: 0.7267 - val_loss: 0.1036 - val_accuracy: 0.7473
# Epoch 27/50
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0895 - accuracy: 0.7270 - val_loss: 0.1016 - val_accuracy: 0.7446
# Epoch 28/50
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0847 - accuracy: 0.7269 - val_loss: 0.1043 - val_accuracy: 0.7465
# Epoch 29/50
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0831 - accuracy: 0.7267 - val_loss: 0.1057 - val_accuracy: 0.7476
# Epoch 30/50
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0820 - accuracy: 0.7271 - val_loss: 0.1000 - val_accuracy: 0.7470
# Epoch 31/50
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0800 - accuracy: 0.7271 - val_loss: 0.1049 - val_accuracy: 0.7485
# Epoch 32/50
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0772 - accuracy: 0.7266 - val_loss: 0.1029 - val_accuracy: 0.7467
# Epoch 33/50
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0799 - accuracy: 0.7272 - val_loss: 0.0963 - val_accuracy: 0.7467
# Epoch 34/50
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0782 - accuracy: 0.7273 - val_loss: 0.1013 - val_accuracy: 0.7486
# Epoch 35/50
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0739 - accuracy: 0.7269 - val_loss: 0.0992 - val_accuracy: 0.7476
# Epoch 36/50
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0739 - accuracy: 0.7270 - val_loss: 0.1021 - val_accuracy: 0.7507
# Epoch 37/50
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0722 - accuracy: 0.7272 - val_loss: 0.0998 - val_accuracy: 0.7499
# Epoch 38/50
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0721 - accuracy: 0.7273 - val_loss: 0.0992 - val_accuracy: 0.7509
# Epoch 39/50
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0701 - accuracy: 0.7271 - val_loss: 0.0976 - val_accuracy: 0.7509
# Epoch 40/50
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0719 - accuracy: 0.7275 - val_loss: 0.0946 - val_accuracy: 0.7499
# Epoch 41/50
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0695 - accuracy: 0.7272 - val_loss: 0.0997 - val_accuracy: 0.7519
# Epoch 42/50
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0673 - accuracy: 0.7272 - val_loss: 0.0988 - val_accuracy: 0.7515
# Epoch 43/50
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0667 - accuracy: 0.7273 - val_loss: 0.0965 - val_accuracy: 0.7521
# Epoch 44/50
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0667 - accuracy: 0.7275 - val_loss: 0.0976 - val_accuracy: 0.7520
# Epoch 45/50
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0645 - accuracy: 0.7272 - val_loss: 0.0978 - val_accuracy: 0.7529
# Epoch 46/50
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0644 - accuracy: 0.7273 - val_loss: 0.0947 - val_accuracy: 0.7513
# Epoch 47/50
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0653 - accuracy: 0.7274 - val_loss: 0.0974 - val_accuracy: 0.7518
# Epoch 48/50
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0627 - accuracy: 0.7277 - val_loss: 0.0941 - val_accuracy: 0.7517
# Epoch 49/50
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0610 - accuracy: 0.7274 - val_loss: 0.0951 - val_accuracy: 0.7520
# Epoch 50/50
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0600 - accuracy: 0.7274 - val_loss: 0.0967 - val_accuracy: 0.7532

# %% [markdown]
# You can use the following cell to batch plot som validation.

# %%
cnn_helper.plot_prediction(model, next(val_generator), BATCH_SIZE)
# Out:
# 1/1 [==============================] - 0s 190ms/step

# %% [markdown]
# ## Tuning of the model
# Try improving on your model by changing the learning rate, epochs, activation function or any other parameters you want.

# %% [markdown]
# # Other models
# Lets be honest, this was somewhat of a chore to code without GPT - and if you did use GPT and got it to work, it's still a bit a work, no? We can be even lazier, and use predfined models to simplify the construction of your models.
#
# you will now use the `segmentation_model` python library ( it should be installed already, but if you get an error, install using `pip install segmentation_model`).
#
# You can read more about the `segmentation_model` library at https://github.com/qubvel/segmentation_models.
#
# ## List of relevant models:
#
# | Unet | Linknet |
# | --- | --- |
# | <img width="500px" src="https://raw.githubusercontent.com/qubvel/segmentation_models/master/images/unet.png" title="UNet"/> | <img width="500px" src="https://github.com/qubvel/segmentation_models/raw/master/images/linknet.png" title="Linknet"/> |
#
#
#
# ## List of backbones:
#
# | Type | Names |
# | --- | --- |
# | VGG | `vgg16` `vgg19` |
# | ResNet | `resnet18` `resnet34` `resnet50` `resnet101` `resnet152` |
# | SE-ResNet | `seresnet18` `seresnet34` `seresnet50` `seresnet101` `seresnet152` |
# | ResNeXt | `resnext50` `resnext101` |
# | SE-ResNeXt | `seresnext50` `seresnext101` |
# | SENet154 | `senet154` |
# | DenseNet | `densenet121` `densenet169` `densenet201` |
# | Inception | `inceptionv3` `inceptionresnetv2` |
# | MobileNet | `mobilenet` `mobilenetv2` |
# | EfficientNet | `efficientnetb0` `efficientnetb1` `efficientnetb2` `efficientnetb3` `efficientnetb4` `efficientnetb5` `efficientnetb6` `efficientnetb7` |

# %% [markdown]
# You will now repeat the segmentation using backbones from the list. You do so by changing the text in the cell below from 'vgg16' to something else, such as 'vgg19', 'resnet18', or 'inceptionv3'. Select three different version, and rerun the cell. you will be asked on the quiz later on what model you chose, and then how the rated your three chosen models.

# %%
#Select Backbone here
backbone = 'inceptionv3'

# Let's load the Unet model
model = sm.Unet(
    backbone,
    encoder_weights=None,
    classes=NUM_CLASSES,
    activation='softmax',
    input_shape=(IMG_SIZE,IMG_SIZE,3)
)

# %%
#Print the model summary:
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 128, 128, 64  1792        ['input_3[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 128, 128, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 64, 64, 64)   0           ['block1_conv2[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 64, 64, 128)  73856       ['block1_pool[0][0]']
#
#  block2_conv2 (Conv2D)          (None, 64, 64, 128)  147584      ['block2_conv1[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 32, 32, 128)  0           ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 32, 32, 256)  295168      ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv2[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 16, 16, 256)  0           ['block3_conv3[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 16, 16, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv2[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 8, 8, 512)    0           ['block4_conv3[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 8, 8, 512)    2359808     ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 8, 8, 512)    2359808     ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 8, 8, 512)    2359808     ['block5_conv2[0][0]']
#
#  block5_pool (MaxPooling2D)     (None, 4, 4, 512)    0           ['block5_conv3[0][0]']
#
#  center_block1_conv (Conv2D)    (None, 4, 4, 512)    2359296     ['block5_pool[0][0]']
#
#  center_block1_bn (BatchNormali  (None, 4, 4, 512)   2048        ['center_block1_conv[0][0]']
#  zation)
#
#  center_block1_relu (Activation  (None, 4, 4, 512)   0           ['center_block1_bn[0][0]']
#  )
#
#  center_block2_conv (Conv2D)    (None, 4, 4, 512)    2359296     ['center_block1_relu[0][0]']
#
#  center_block2_bn (BatchNormali  (None, 4, 4, 512)   2048        ['center_block2_conv[0][0]']
#  zation)
#
#  center_block2_relu (Activation  (None, 4, 4, 512)   0           ['center_block2_bn[0][0]']
#  )
#
#  decoder_stage0_upsampling (UpS  (None, 8, 8, 512)   0           ['center_block2_relu[0][0]']
#  ampling2D)
#
#  decoder_stage0_concat (Concate  (None, 8, 8, 1024)  0           ['decoder_stage0_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'block5_conv3[0][0]']
#
#  decoder_stage0a_conv (Conv2D)  (None, 8, 8, 256)    2359296     ['decoder_stage0_concat[0][0]']
#
#  decoder_stage0a_bn (BatchNorma  (None, 8, 8, 256)   1024        ['decoder_stage0a_conv[0][0]']
#  lization)
#
#  decoder_stage0a_relu (Activati  (None, 8, 8, 256)   0           ['decoder_stage0a_bn[0][0]']
#  on)
#
#  decoder_stage0b_conv (Conv2D)  (None, 8, 8, 256)    589824      ['decoder_stage0a_relu[0][0]']
#
#  decoder_stage0b_bn (BatchNorma  (None, 8, 8, 256)   1024        ['decoder_stage0b_conv[0][0]']
#  lization)
#
#  decoder_stage0b_relu (Activati  (None, 8, 8, 256)   0           ['decoder_stage0b_bn[0][0]']
#  on)
#
#  decoder_stage1_upsampling (UpS  (None, 16, 16, 256)  0          ['decoder_stage0b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage1_concat (Concate  (None, 16, 16, 768)  0          ['decoder_stage1_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'block4_conv3[0][0]']
#
#  decoder_stage1a_conv (Conv2D)  (None, 16, 16, 128)  884736      ['decoder_stage1_concat[0][0]']
#
#  decoder_stage1a_bn (BatchNorma  (None, 16, 16, 128)  512        ['decoder_stage1a_conv[0][0]']
#  lization)
#
#  decoder_stage1a_relu (Activati  (None, 16, 16, 128)  0          ['decoder_stage1a_bn[0][0]']
#  on)
#
#  decoder_stage1b_conv (Conv2D)  (None, 16, 16, 128)  147456      ['decoder_stage1a_relu[0][0]']
#
#  decoder_stage1b_bn (BatchNorma  (None, 16, 16, 128)  512        ['decoder_stage1b_conv[0][0]']
#  lization)
#
#  decoder_stage1b_relu (Activati  (None, 16, 16, 128)  0          ['decoder_stage1b_bn[0][0]']
#  on)
#
#  decoder_stage2_upsampling (UpS  (None, 32, 32, 128)  0          ['decoder_stage1b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage2_concat (Concate  (None, 32, 32, 384)  0          ['decoder_stage2_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'block3_conv3[0][0]']
#
#  decoder_stage2a_conv (Conv2D)  (None, 32, 32, 64)   221184      ['decoder_stage2_concat[0][0]']
#
#  decoder_stage2a_bn (BatchNorma  (None, 32, 32, 64)  256         ['decoder_stage2a_conv[0][0]']
#  lization)
#
#  decoder_stage2a_relu (Activati  (None, 32, 32, 64)  0           ['decoder_stage2a_bn[0][0]']
#  on)
#
#  decoder_stage2b_conv (Conv2D)  (None, 32, 32, 64)   36864       ['decoder_stage2a_relu[0][0]']
#
#  decoder_stage2b_bn (BatchNorma  (None, 32, 32, 64)  256         ['decoder_stage2b_conv[0][0]']
#  lization)
#
#  decoder_stage2b_relu (Activati  (None, 32, 32, 64)  0           ['decoder_stage2b_bn[0][0]']
#  on)
#
#  decoder_stage3_upsampling (UpS  (None, 64, 64, 64)  0           ['decoder_stage2b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage3_concat (Concate  (None, 64, 64, 192)  0          ['decoder_stage3_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'block2_conv2[0][0]']
#
#  decoder_stage3a_conv (Conv2D)  (None, 64, 64, 32)   55296       ['decoder_stage3_concat[0][0]']
#
#  decoder_stage3a_bn (BatchNorma  (None, 64, 64, 32)  128         ['decoder_stage3a_conv[0][0]']
#  lization)
#
#  decoder_stage3a_relu (Activati  (None, 64, 64, 32)  0           ['decoder_stage3a_bn[0][0]']
#  on)
#
#  decoder_stage3b_conv (Conv2D)  (None, 64, 64, 32)   9216        ['decoder_stage3a_relu[0][0]']
#
#  decoder_stage3b_bn (BatchNorma  (None, 64, 64, 32)  128         ['decoder_stage3b_conv[0][0]']
#  lization)
#
#  decoder_stage3b_relu (Activati  (None, 64, 64, 32)  0           ['decoder_stage3b_bn[0][0]']
#  on)
#
#  decoder_stage4_upsampling (UpS  (None, 128, 128, 32  0          ['decoder_stage3b_relu[0][0]']
#  ampling2D)                     )
#
#  decoder_stage4a_conv (Conv2D)  (None, 128, 128, 16  4608        ['decoder_stage4_upsampling[0][0]
#                                 )                                ']
#
#  decoder_stage4a_bn (BatchNorma  (None, 128, 128, 16  64         ['decoder_stage4a_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4a_relu (Activati  (None, 128, 128, 16  0          ['decoder_stage4a_bn[0][0]']
#  on)                            )
#
#  decoder_stage4b_conv (Conv2D)  (None, 128, 128, 16  2304        ['decoder_stage4a_relu[0][0]']
#                                 )
#
#  decoder_stage4b_bn (BatchNorma  (None, 128, 128, 16  64         ['decoder_stage4b_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4b_relu (Activati  (None, 128, 128, 16  0          ['decoder_stage4b_bn[0][0]']
#  on)                            )
#
#  final_conv (Conv2D)            (None, 128, 128, 3)  435         ['decoder_stage4b_relu[0][0]']
#
#  softmax (Activation)           (None, 128, 128, 3)  0           ['final_conv[0][0]']
#
# ==================================================================================================
# Total params: 23,752,563
# Trainable params: 23,748,531
# Non-trainable params: 4,032
# __________________________________________________________________________________________________

# %% [markdown]
# ### Define, Compile, and Train the new model:
#
# You will now define, compile, and train the new model you selected from the module with the same parameters as your best run with your self-built model.

# %%
#compile here:
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
#train model here:
model.fit_generator(
    generator=train_generator,
    steps_per_epoch=train_steps, 
    epochs=30,
    validation_data=val_generator,
    validation_steps=val_steps, 
)
# Out:
# Epoch 1/30
# /tmp/ipykernel_80959/2555264483.py:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(
# 2024-01-28 20:05:21.753469: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 29/30 [============================>.] - ETA: 0s - loss: 0.6326 - accuracy: 0.6786
# 2024-01-28 20:05:32.895256: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 30/30 [==============================] - 12s 63ms/step - loss: 0.6279 - accuracy: 0.6795 - val_loss: 0.9699 - val_accuracy: 0.9996
# Epoch 2/30
# 30/30 [==============================] - 1s 29ms/step - loss: 0.4368 - accuracy: 0.7156 - val_loss: 0.7955 - val_accuracy: 1.0000
# Epoch 3/30
# 30/30 [==============================] - 1s 28ms/step - loss: 0.3376 - accuracy: 0.7214 - val_loss: 0.6410 - val_accuracy: 0.9998
# Epoch 4/30
# 30/30 [==============================] - 1s 29ms/step - loss: 0.2511 - accuracy: 0.7251 - val_loss: 0.6328 - val_accuracy: 0.9594
# Epoch 5/30
# 30/30 [==============================] - 1s 29ms/step - loss: 0.1931 - accuracy: 0.7253 - val_loss: 0.5988 - val_accuracy: 0.9226
# Epoch 6/30
# 30/30 [==============================] - 1s 28ms/step - loss: 0.1609 - accuracy: 0.7255 - val_loss: 0.5170 - val_accuracy: 0.8818
# Epoch 7/30
# 30/30 [==============================] - 1s 28ms/step - loss: 0.1390 - accuracy: 0.7257 - val_loss: 0.4595 - val_accuracy: 0.8615
# Epoch 8/30
# 30/30 [==============================] - 1s 29ms/step - loss: 0.1221 - accuracy: 0.7256 - val_loss: 0.2937 - val_accuracy: 0.7937
# Epoch 9/30
# 30/30 [==============================] - 1s 29ms/step - loss: 0.1067 - accuracy: 0.7263 - val_loss: 0.2749 - val_accuracy: 0.7944
# Epoch 10/30
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0964 - accuracy: 0.7261 - val_loss: 0.1671 - val_accuracy: 0.7540
# Epoch 11/30
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0868 - accuracy: 0.7261 - val_loss: 0.1659 - val_accuracy: 0.7502
# Epoch 12/30
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0796 - accuracy: 0.7266 - val_loss: 0.2849 - val_accuracy: 0.8045
# Epoch 13/30
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0731 - accuracy: 0.7265 - val_loss: 0.2515 - val_accuracy: 0.7862
# Epoch 14/30
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0694 - accuracy: 0.7265 - val_loss: 0.2592 - val_accuracy: 0.7823
# Epoch 15/30
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0688 - accuracy: 0.7267 - val_loss: 0.1018 - val_accuracy: 0.7475
# Epoch 16/30
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0641 - accuracy: 0.7262 - val_loss: 0.0747 - val_accuracy: 0.7378
# Epoch 17/30
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0602 - accuracy: 0.7268 - val_loss: 0.0946 - val_accuracy: 0.7412
# Epoch 18/30
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0572 - accuracy: 0.7265 - val_loss: 0.1165 - val_accuracy: 0.7471
# Epoch 19/30
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0541 - accuracy: 0.7266 - val_loss: 0.1326 - val_accuracy: 0.7330
# Epoch 20/30
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0506 - accuracy: 0.7266 - val_loss: 0.1337 - val_accuracy: 0.7318
# Epoch 21/30
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0494 - accuracy: 0.7265 - val_loss: 0.2299 - val_accuracy: 0.7123
# Epoch 22/30
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0494 - accuracy: 0.7267 - val_loss: 0.0715 - val_accuracy: 0.7312
# Epoch 23/30
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0481 - accuracy: 0.7266 - val_loss: 0.1220 - val_accuracy: 0.7291
# Epoch 24/30
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0454 - accuracy: 0.7268 - val_loss: 0.0902 - val_accuracy: 0.7428
# Epoch 25/30
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0416 - accuracy: 0.7266 - val_loss: 0.0583 - val_accuracy: 0.7379
# Epoch 26/30
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0410 - accuracy: 0.7269 - val_loss: 0.0615 - val_accuracy: 0.7384
# Epoch 27/30
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0391 - accuracy: 0.7269 - val_loss: 0.0647 - val_accuracy: 0.7402
# Epoch 28/30
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0381 - accuracy: 0.7266 - val_loss: 0.0593 - val_accuracy: 0.7366
# Epoch 29/30
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0366 - accuracy: 0.7269 - val_loss: 0.0761 - val_accuracy: 0.7465
# Epoch 30/30
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0359 - accuracy: 0.7269 - val_loss: 0.0942 - val_accuracy: 0.7479

# %%
#Print prediction the same way as before:

cnn_helper.plot_prediction (model, next(val_generator), BATCH_SIZE)
# Out:
# 1/1 [==============================] - 1s 517ms/step
